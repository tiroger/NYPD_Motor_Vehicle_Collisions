# %%
import numpy as np
import pandas as pd

# %%
augmented_data = pd.read_csv('Resources/augmented_raw_data.csv', low_memory=False)

# %%
augmented_data.head()
# Out:
#          DATE  TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  06/14/2019  0:00     BRONX    10461  40.836327 -73.827614
# 1  06/14/2019  0:00  BROOKLYN    11207  40.685127 -73.906430
# 2  06/14/2019  0:00  BROOKLYN    11212  40.661655 -73.927950
# 3  06/14/2019  0:00    QUEENS    11413  40.675213 -73.737800
# 4  06/14/2019  0:00     BRONX    10466  40.887420 -73.894490
#
#                   LOCATION                    ON STREET NAME  \
# 0  (40.836327, -73.827614)  CROSBY AVENUE
# 1   (40.685127, -73.90643)  PILLING STREET
# 2   (40.661655, -73.92795)                               NaN
# 3    (40.675213, -73.7378)  MERRICK BOULEVARD
# 4    (40.88742, -73.89449)  MAJOR DEEGAN EXPRESSWAY
#
#   CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0    BAISLEY AVENUE                                       NaN  ...
# 1  EVERGREEN AVENUE                                       NaN  ...
# 2               NaN  950       RUTLAND ROAD                    ...
# ...

# %%
# Filtering for duplicate rows grouped by location
duplicated_rows = pd.concat(g for _, g in raw_data.groupby(['ON STREET NAME']) if len(g) > 1)

# %%
duplicated_rows.shape
# Out:
# (984606, 29)

# %%
duplicated_rows.head()
# Out:
#               DATE   TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 660829  07/24/2016   9:01      MANHATTAN    10028  40.773709 -73.947934
# 661988  07/22/2016  19:30      MANHATTAN    10001  40.748466 -73.990530
# 662919  07/21/2016   8:05       BROOKLYN    11220  40.666094 -73.795390
# 673418  07/04/2016  15:03  STATEN ISLAND    10301  40.619168 -74.106521
# 675711  06/30/2016  14:00       BROOKLYN    11237  40.698719 -73.919127
#
#                          LOCATION                    ON STREET NAME  \
# 660829  (40.7737086, -73.9479338)
# 661988  (40.7484656, -73.9905298)
# 662919  (40.6660939, -73.7953901)
# 673418  (40.6191681, -74.1065209)
# 675711   (40.698719, -73.9191269)
#
#                        CROSS STREET NAME  \
# 660829
# 661988
# 662919
# 673418
# 675711
#
#                                  OFF STREET NAME  ...  \
# 660829  516 EAST 83 STREET                        ...
# 661988  146 WEST 31 STREET                        ...
# ...

# %%
duplicated_rows['ON STREET NAME'].unique()
# Out:
# array(['                                ',
#        '1 AVENUE                        ',
#        '1 Avenue                        ', ...,
#        'willow road east                ',
#        'woodhaven blvd                  ',
#        'york avenue                     '], dtype=object)

# %%
duplicated_rows['ON STREET NAME'].replace('                                ', np.nan, inplace=True)
duplicated_rows.head()
# Out:
#               DATE   TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 660829  07/24/2016   9:01      MANHATTAN    10028  40.773709 -73.947934
# 661988  07/22/2016  19:30      MANHATTAN    10001  40.748466 -73.990530
# 662919  07/21/2016   8:05       BROOKLYN    11220  40.666094 -73.795390
# 673418  07/04/2016  15:03  STATEN ISLAND    10301  40.619168 -74.106521
# 675711  06/30/2016  14:00       BROOKLYN    11237  40.698719 -73.919127
#
#                          LOCATION ON STREET NAME  \
# 660829  (40.7737086, -73.9479338)            NaN
# 661988  (40.7484656, -73.9905298)            NaN
# 662919  (40.6660939, -73.7953901)            NaN
# 673418  (40.6191681, -74.1065209)            NaN
# 675711   (40.698719, -73.9191269)            NaN
#
#                        CROSS STREET NAME  \
# 660829
# 661988
# 662919
# 673418
# 675711
#
#                                  OFF STREET NAME  ...  \
# 660829  516 EAST 83 STREET                        ...
# ...

# %%
duplicated_rows_w_streets = duplicated_rows[duplicated_rows['ON STREET NAME'].notna()]

# %%
sorted_duplicated_rows_w_streets = duplicated_rows_w_streets.sort_values('ON STREET NAME')
sorted_duplicated_rows_w_streets.head(10000)
# Out:
#                DATE   TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 401      06/14/2019  19:30      MANHATTAN    10017  40.753242 -73.966620
# 984352   02/10/2015   8:15      MANHATTAN    10029  40.783934 -73.944225
# 983954   02/10/2015  12:30      MANHATTAN    10010  40.736791 -73.978497
# 983896   02/10/2015  11:06      MANHATTAN    10022  40.755130 -73.965241
# 983867   02/10/2015  10:30       BROOKLYN    11220  40.646504 -74.023207
# 983848   02/10/2015  10:00      MANHATTAN    10009  40.725777 -73.986604
# 983823   02/11/2015   9:25      MANHATTAN    10021  40.765868 -73.957413
# 983800   02/11/2015   8:59      MANHATTAN    10010  40.736791 -73.978497
# 983559   02/11/2015  18:20      MANHATTAN    10029  40.787064 -73.941936
# 983496   02/11/2015  16:45      MANHATTAN    10065  40.763366 -73.959241
# 982951   02/12/2015  16:56      MANHATTAN    10022  40.757639 -73.963410
# 981368   02/15/2015  22:10      MANHATTAN    10029  40.783934 -73.944225
# ...
